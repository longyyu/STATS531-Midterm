# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set(style='darkgrid')

# %%
df = pd.read_csv('michigan_huron_level.csv', sep=',')[['Date', 'MSL (ft)']]
df
# Out:
#            Date  MSL (ft)
# 0    2010/02/01   577.914
# 1    2010/03/01   577.780
# 2    2010/04/01   577.802
# 3    2010/05/01   577.861
# 4    2010/06/01   578.083
# ..          ...       ...
# 126  2020/08/01   582.215
# 127  2020/09/01   581.900
# 128  2020/10/01   581.591
# 129  2020/11/01   581.430
# 130  2020/12/01   581.276
#
# [131 rows x 2 columns]

# %%
idx = [2010 + i / 12 for i in range(12 * 11 - 1)]

# %%
plt.figure(figsize=(12,5))
plt.xticks(np.arange(2010, 2022))
plt.plot(idx, df['MSL (ft)'], '-')
